# %% [markdown]
# <a href="https://colab.research.google.com/github/CharithaGongati/assignment-3/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Progam 1
class Employee:
    num_employees = 0

    def __init__(self, name, family, salary, department):
        self.name = name
        self.family = family
        self.salary = salary
        self.department = department
        Employee.num_employees += 1

    def display_employee_info(self):
        print(f"Name: {self.name}")
        print(f"Family: {self.family}")
        print(f"Salary: ${self.salary}")
        print(f"Department: {self.department}")

    @staticmethod
    def average_salary(employee_list):
        total_salary = sum(emp.salary for emp in employee_list)
        return total_salary / len(employee_list) if len(employee_list) > 0 else 0


class FulltimeEmployee(Employee):
    def __init__(self, name, family, salary, department):
        super().__init__(name, family, salary, department)


# Create instances of Employee class
employee1 = Employee("Charitha Gongati", "Gongati Family", 70000, "HR")
employee2 = Employee("Shreya Jukkana", "Jukanna Family", 65000, "IT")
employee3 = Employee("Renu Kondakindi", "Kondakindi Family", 75000, "Finance")

# Create instances of FulltimeEmployee class
fulltime_employee1 = FulltimeEmployee("Flora Vadla", "Vadla Family", 80000, "Marketing")
fulltime_employee2 = FulltimeEmployee("Akhila Etikela", "Etikela Family", 70000, "Sales")

# Display employee information
employee1.display_employee_info()
print("------------------------")
employee2.display_employee_info()
print("------------------------")
employee3.display_employee_info()
print("------------------------")
fulltime_employee1.display_employee_info()
print("------------------------")
fulltime_employee2.display_employee_info()
print("------------------------")

# Calculate and display average salary
all_employees = [employee1, employee2, employee3, fulltime_employee1, fulltime_employee2]
avg_salary = Employee.average_salary(all_employees)
print(f"Average Salary: ${avg_salary:.2f}")

# Display total number of employees
print(f"Total Number of Employees: {Employee.num_employees}")
# Out:
# Name: Charitha Gongati
# Family: Gongati Family
# Salary: $70000
# Department: HR
# ------------------------
# Name: Shreya Jukkana
# Family: Jukanna Family
# Salary: $65000
# Department: IT
# ------------------------
# Name: Renu Kondakindi
# Family: Kondakindi Family
# Salary: $75000
# Department: Finance
# ------------------------
# Name: Flora Vadla
# Family: Vadla Family
# Salary: $80000
# Department: Marketing
# ------------------------
# Name: Akhila Etikela
# Family: Etikela Family
# Salary: $70000
# Department: Sales
# ------------------------
# Average Salary: $72000.00
# Total Number of Employees: 5

# %%
#Program 2
import numpy as np

# Create a random vector of size 20 with floats in the range 1-20
random_vector = np.random.uniform(1, 20, 20)

# Reshape the vector into a 4x5 array
reshaped_array = random_vector.reshape(4, 5)

# Find the indices of the maximum value in each row
max_indices = np.argmax(reshaped_array, axis=1)

# Replace the maximum value in each row with 0
for row_idx, col_idx in enumerate(max_indices):
    reshaped_array[row_idx, col_idx] = 0

print("Original random vector:")
print(random_vector)
print("\nReshaped array:")
print(reshaped_array)
# Out:
# Original random vector:
# [ 4.98589207  0.          6.94972086  9.07834911  3.47120957  0.
#  16.92986358 17.97669728  5.14923704  9.00544218  1.82727201 12.67490516
#  15.26556059  5.17839119  0.          1.41086356  4.11141186  0.
#   8.58023934 10.82044301]
#
# Reshaped array:
# [[ 4.98589207  0.          6.94972086  9.07834911  3.47120957]
#  [ 0.         16.92986358 17.97669728  5.14923704  9.00544218]
#  [ 1.82727201 12.67490516 15.26556059  5.17839119  0.        ]
#  [ 1.41086356  4.11141186  0.          8.58023934 10.82044301]]
